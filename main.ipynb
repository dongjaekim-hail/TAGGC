# %% [markdown]
# <a href="https://colab.research.google.com/github/dongjaekim-hail/TAGGC/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gdown

# %%
# !gdown --id '1aeIa-jyufzO9h13rEGerBcMwR32ckrVf' -O all_sources.zip
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1aeIa-jyufzO9h13rEGerBcMwR32ckrVf
# From (redirected): https://drive.google.com/uc?id=1aeIa-jyufzO9h13rEGerBcMwR32ckrVf&confirm=t&uuid=6a938876-ac48-42fa-a2ff-a4f4213a79ef
# To: /content/all_sources.zip
# 100% 339M/339M [00:15<00:00, 22.0MB/s]

# %%
# !ls -lh all_sources.zip
# Out:
# -rw-r--r-- 1 root root 324M Oct 30 08:47 all_sources.zip

# %%
# !ls
# Out:
# all_sources.zip  sample_data

# %%
# !unzip all_sources.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: data/pro_lone_total_29/val/001056/data000002.npy
#   inflating: data/pro_lone_total_29/val/001056/data000003.npy
#   inflating: data/pro_lone_total_29/val/001056/data000004.npy
#   inflating: data/pro_lone_total_29/val/001056/data000005.npy
#   inflating: data/pro_lone_total_29/val/001056/data000006.npy
#   inflating: data/pro_lone_total_29/val/001056/data000007.npy
#   inflating: data/pro_lone_total_29/val/001056/data000008.npy
#   inflating: data/pro_lone_total_29/val/001056/data000009.npy
#   inflating: data/pro_lone_total_29/val/001056/data000010.npy
#   inflating: data/pro_lone_total_29/val/001056/dones.pkl
#   inflating: data/pro_lone_total_29/val/001056/metadata.pkl
#   inflating: data/pro_lone_total_29/val/001056/rewards.pkl
#    creating: data/pro_lone_total_29/val/001057/
#   inflating: data/pro_lone_total_29/val/001057/000000.png
#   inflating: data/pro_lone_total_29/val/001057/000001.png
# ...

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu124
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 14.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.0/363.0 MB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 103.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.4/883.4 kB 63.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.6 MB/s eta 0:00:00
# ...

# %%
# !ls
# Out:
# all_sources.zip  evaluate_custom_bigdata_dk.py	sample_data
# checkpoint	 evaluation			train_custom_bigdata_dk.py
# configs		 model				training
# data		 readme.md			utils
# dataset		 requirements.txt		Vgg_train_bigdata_dk.py
# Dockerfile	 results
# environment.yml  run.sh

# %%
# !wandb offline # 만약 wandb로 기록해서 보고싶다면 이 부분에서 online 으로 하고 wandb login 후 계정정보 입력
# Out:
# W&B offline. Running your script from this directory will only write metadata locally. Use wandb disabled to completely turn off W&B.

# %%
# !source run.sh
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch [14/20]:  33% 163/495 [00:15<00:32, 10.37it/s, Batch Loss=0.156, Batch Accuracy=95.5]
# Epoch [14/20]:  33% 163/495 [00:15<00:32, 10.37it/s, Batch Loss=0.122, Batch Accuracy=97]
# Epoch [14/20]:  33% 163/495 [00:15<00:32, 10.37it/s, Batch Loss=0.183, Batch Accuracy=93]
# Epoch [14/20]:  33% 165/495 [00:15<00:31, 10.41it/s, Batch Loss=0.183, Batch Accuracy=93]
# Epoch [14/20]:  33% 165/495 [00:15<00:31, 10.41it/s, Batch Loss=0.143, Batch Accuracy=95]
# Epoch [14/20]:  33% 165/495 [00:16<00:31, 10.41it/s, Batch Loss=0.243, Batch Accuracy=91.5]
# Epoch [14/20]:  34% 167/495 [00:16<00:31, 10.39it/s, Batch Loss=0.243, Batch Accuracy=91.5]
# Epoch [14/20]:  34% 167/495 [00:16<00:31, 10.39it/s, Batch Loss=0.133, Batch Accuracy=97]
# Epoch [14/20]:  34% 167/495 [00:16<00:31, 10.39it/s, Batch Loss=0.196, Batch Accuracy=94]
# Epoch [14/20]:  34% 169/495 [00:16<00:31, 10.39it/s, Batch Loss=0.196, Batch Accuracy=94]
# ...
